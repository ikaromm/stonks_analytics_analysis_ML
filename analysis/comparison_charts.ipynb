# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("excel/data.csv", sep=";", encoding="utf-8")
figura = plt.figure(figsize=(15,20))
eixo = figura.gca()
dataset.hist(ax = eixo);
# Out:
# /tmp/ipykernel_9426/3979762190.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   dataset.hist(ax = eixo);
